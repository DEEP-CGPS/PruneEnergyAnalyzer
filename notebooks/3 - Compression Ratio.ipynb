# %% [markdown]
# # Energy Consumption Analysis with Pruning
# #
# This notebook loads a CSV file with experimental results and uses the `AnalysisPlotter` class to visualize the data.

# %%
import sys
import os

lib_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
if lib_path not in sys.path:
    sys.path.append(lib_path)

import pandas as pd
from PruneEnergyAnalizer import AnalysisPlotter, parse_model_name, add_compression_ratio

# %%
# Load the CSV file
df = pd.read_csv("results_v18.csv")
df
# Out:
#                                             MODEL_NAME  BATCH_SIZE  \
# 0    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...           1
# 1    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...           8
# 2    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...          16
# 3    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...          32
# 4    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...          64
# ..                                                 ...         ...
# 325  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...           1
# 326  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...           8
# 327  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...          16
# 328  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...          32
# 329  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...          64
#
#      Mean Time per Sample (s)           FPS  STD Time per Sample (s)  \
# 0                    0.001051    951.050459             8.149121e-05
# 1                    0.000143   6986.317633             2.247262e-05
# 2                    0.000080  12517.014326             5.688501e-06
# 3                    0.000064  15572.893992             5.565086e-07
# 4                    0.000053  18695.209667             5.230126e-07
# ..                        ...           ...                      ...
# 325                  0.001142    875.545688             1.306459e-04
# 326                  0.000167   5985.722286             1.747937e-05
# 327                  0.000119   8433.503900             9.069218e-08
# 328                  0.000100   9959.311473             3.384769e-08
# 329                  0.000082  12152.227360             2.240934e-07
#
#      Mean Energy per Sample (J)  STD Energy per Sample (J)  Parameters  \
# 0                      0.176480                   0.017662    19684806
# 1                      0.036092                   0.003658    19684806
# 2                      0.023516                   0.001628    19684806
# 3                      0.019233                   0.000754    19684806
# 4                      0.016532                   0.000366    19684806
# ..                          ...                        ...         ...
# 325                    0.272282                   0.036279    40026038
# 326                    0.050303                   0.005614    40026038
# 327                    0.036408                   0.001931    40026038
# 328                    0.030444                   0.000431    40026038
# 329                    0.025805                   0.000490    40026038
#
#            FLOPs
# 0      234326646
# 1     1874613168
# 2     3749226336
# 3     7498452672
# 4    14996905344
# ..           ...
# 325    468902342
# 326   3751218736
# 327   7502437472
# 328  15004874944
# 329  30009749888
#
# [330 rows x 9 columns]

# %%
df = parse_model_name(df)
df[["MODEL_NAME", "GPR", "Architecture", "Pruning Distribution"]]
# Out:
#                                             MODEL_NAME  GPR Architecture  \
# 0    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...   45      AlexNet
# 1    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...   45      AlexNet
# 2    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...   45      AlexNet
# 3    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...   45      AlexNet
# 4    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...   45      AlexNet
# ..                                                 ...  ...          ...
# 325  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...   20      AlexNet
# 326  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...   20      AlexNet
# 327  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...   20      AlexNet
# 328  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...   20      AlexNet
# 329  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...   20      AlexNet
#
#     Pruning Distribution
# 0                    PD1
# 1                    PD1
# 2                    PD1
# 3                    PD1
# 4                    PD1
# ..                   ...
# 325                  PD1
# 326                  PD1
# 327                  PD1
# 328                  PD1
# 329                  PD1
#
# [330 rows x 4 columns]

# %%
# Create an instance of AnalysisPlotter
plotter = AnalysisPlotter(
    dataframe=df, 
    x_column="GPR", 
    y_column="Mean Energy per Sample (J)", 
    title="Impact of Pruning on Energy Consumption"
)

# Generate the plot for a specific architecture, pruning distributions, and batch size
plotter.plot_data(
    architectures=["AlexNet"],
    pruning_distributions=["PD1", "PD2", "PD3", "PD4", "PD5"],
    batch_sizes=[16],
    patience=3,  # Number of iterations without significant improvement
    min_delta=0.05  # Minimum variation to consider stabilization
    )
# Out:
# [ 0  5 10 15 20 25 30 35 40 45 50 55 60 65] [0.03915802 0.04366778 0.04179285 0.03955609 0.03640784 0.02716633
#  0.03178136 0.02751086 0.02613081 0.0235159  0.01837705 0.02113623
#  0.02009618 0.01959731] [0.0003774  0.00176429 0.00161745 0.00173446 0.0019309  0.00027062
#  0.0012094  0.00214926 0.00169591 0.00162767 0.00191073 0.00262642
#  0.00206062 0.00186069]
# [ 0  5 10 15 20 25 30 35 40 45 50 55 60 65] [0.03915802 0.04255097 0.04115774 0.03844812 0.03150928 0.03143449
#  0.03021351 0.03099312 0.02447068 0.02323115 0.02030127 0.01939234
#  0.01859589 0.01975217] [0.0003774  0.00017414 0.00201979 0.00163016 0.00129117 0.00089846
#  0.0019152  0.0014357  0.00164089 0.00354298 0.00172205 0.00256728
#  0.00223023 0.00249274]
# [ 0  5 10 15 20 25 30 35 40 45 50 55 60 65] [0.03915802 0.04330097 0.04384682 0.03987853 0.03716766 0.03657505
#  0.03027989 0.02929997 0.02451646 0.02284565 0.02081691 0.02192062
#  0.01996761 0.01935495] [0.0003774  0.00201867 0.00159401 0.00120765 0.00208505 0.00191765
#  0.00185093 0.00186216 0.00186499 0.00196503 0.00205497 0.00305029
#  0.00318496 0.00164987]
# [ 0  5 10 15 20 25 30 35 40 45 50 55 60 65] [0.03915802 0.04159986 0.04092018 0.04046531 0.03363076 0.03241457
#  0.03096073 0.02807029 0.02525422 0.01997234 0.02059787 0.02120497
#  0.01924842 0.01788681] [0.0003774  0.00205228 0.00194581 0.00193693 0.00195502 0.0016379
#  0.0008636  0.00140724 0.0020146  0.00162473 0.00305665 0.00252948
#  0.00179738 0.00172235]
# [ 0  5 10 15 20 25 30 35 40 45 50 55 60 65] [0.03915802 0.04480004 0.04255469 0.03772375 0.0357166  0.03247565
#  0.03213741 0.02653206 0.02325232 0.02450784 0.02051951 0.0223109
#  0.02014021 0.01968407] [0.0003774  0.00208504 0.00165126 0.00180761 0.00193062 0.00203088
#  0.00172493 0.00173289 0.00175551 0.00329684 0.00188872 0.00316918
#  0.00181543 0.00185753]

# %%
unpruned_models = ["AlexNet_DATASET_UNPRUNED.pth"]

# Add compression ratio column based on 'Parameters'
df = add_compression_ratio(df, unpruned_names=unpruned_models, metric="Parameters")
df = add_compression_ratio(df, unpruned_names=unpruned_models, metric="FLOPs")
df
# Out:
#                                             MODEL_NAME  BATCH_SIZE  \
# 0    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...           1
# 1    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...           8
# 2    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...          16
# 3    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...          32
# 4    AlexNet_DATASET_random_PD1_GPR-45_PRUNED_SEED_...          64
# ..                                                 ...         ...
# 325  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...           1
# 326  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...           8
# 327  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...          16
# 328  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...          32
# 329  AlexNet_DATASET_random_PD1_GPR-20_PRUNED_SEED_...          64
#
#      Mean Time per Sample (s)           FPS  STD Time per Sample (s)  \
# 0                    0.001051    951.050459             8.149121e-05
# 1                    0.000143   6986.317633             2.247262e-05
# 2                    0.000080  12517.014326             5.688501e-06
# 3                    0.000064  15572.893992             5.565086e-07
# 4                    0.000053  18695.209667             5.230126e-07
# ..                        ...           ...                      ...
# 325                  0.001142    875.545688             1.306459e-04
# 326                  0.000167   5985.722286             1.747937e-05
# 327                  0.000119   8433.503900             9.069218e-08
# 328                  0.000100   9959.311473             3.384769e-08
# 329                  0.000082  12152.227360             2.240934e-07
#
#      Mean Energy per Sample (J)  STD Energy per Sample (J)  Parameters  \
# 0                      0.176480                   0.017662    19684806
# 1                      0.036092                   0.003658    19684806
# 2                      0.023516                   0.001628    19684806
# 3                      0.019233                   0.000754    19684806
# 4                      0.016532                   0.000366    19684806
# ..                          ...                        ...         ...
# 325                    0.272282                   0.036279    40026038
# 326                    0.050303                   0.005614    40026038
# 327                    0.036408                   0.001931    40026038
# 328                    0.030444                   0.000431    40026038
# 329                    0.025805                   0.000490    40026038
#
#            FLOPs  GPR Architecture Pruning Distribution  \
# 0      234326646   45      AlexNet                  PD1
# 1     1874613168   45      AlexNet                  PD1
# 2     3749226336   45      AlexNet                  PD1
# 3     7498452672   45      AlexNet                  PD1
# 4    14996905344   45      AlexNet                  PD1
# ..           ...  ...          ...                  ...
# 325    468902342   20      AlexNet                  PD1
# 326   3751218736   20      AlexNet                  PD1
# 327   7502437472   20      AlexNet                  PD1
# 328  15004874944   20      AlexNet                  PD1
# 329  30009749888   20      AlexNet                  PD1
#
#     Compression Ratio (Parameters) [%] Compression Ratio (FLOPs) [%]
# 0                                 68.0                          67.0
# 1                                 68.0                          67.0
# 2                                 68.0                          67.0
# 3                                 68.0                          67.0
# 4                                 68.0                          67.0
# ..                                 ...                           ...
# 325                               34.0                          34.0
# 326                               34.0                          34.0
# 327                               34.0                          34.0
# 328                               34.0                          34.0
# 329                               34.0                          34.0
#
# [330 rows x 14 columns]

# %%
# Create an instance of AnalysisPlotter
plotter = AnalysisPlotter(
    dataframe=df, 
    x_column="Compression Ratio (Parameters) [%]", 
    y_column="Mean Energy per Sample (J)", 
    title="Impact of Pruning on Energy Consumption"
)

# Generate the plot for a specific architecture, pruning distributions, and batch size
plotter.plot_data(
    architectures=["AlexNet"],
    pruning_distributions=["PD1", "PD2", "PD3", "PD4", "PD5"],
    batch_sizes=[16],
    patience=3,  # Number of iterations without significant improvement
    min_delta=0.05  # Minimum variation to consider stabilization
    )
# Out:
# [ 0  9 18 26 34 42 49 56 62 68 73 78 82 86] [0.03915802 0.04366778 0.04179285 0.03955609 0.03640784 0.02716633
#  0.03178136 0.02751086 0.02613081 0.0235159  0.01837705 0.02113623
#  0.02009618 0.01959731] [0.0003774  0.00176429 0.00161745 0.00173446 0.0019309  0.00027062
#  0.0012094  0.00214926 0.00169591 0.00162767 0.00191073 0.00262642
#  0.00206062 0.00186069]
# [ 0 10 21 30 40 48 56 63 70 76 81 86 90 93] [0.03915802 0.04255097 0.04115774 0.03844812 0.03150928 0.03143449
#  0.03021351 0.03099312 0.02447068 0.02323115 0.02030127 0.01939234
#  0.01859589 0.01975217] [0.0003774  0.00017414 0.00201979 0.00163016 0.00129117 0.00089846
#  0.0019152  0.0014357  0.00164089 0.00354298 0.00172205 0.00256728
#  0.00223023 0.00249274]
# [ 0  7 14 21 28 34 40 46 52 58 63 67 72 76] [0.03915802 0.04330097 0.04384682 0.03987853 0.03716766 0.03657505
#  0.03027989 0.02929997 0.02451646 0.02284565 0.02081691 0.02192062
#  0.01996761 0.01935495] [0.0003774  0.00201867 0.00159401 0.00120765 0.00208505 0.00191765
#  0.00185093 0.00186216 0.00186499 0.00196503 0.00205497 0.00305029
#  0.00318496 0.00164987]
# [ 0 10 20 29 38 47 54 61 68 74 79 84 88 91] [0.03915802 0.04159986 0.04092018 0.04046531 0.03363076 0.03241457
#  0.03096073 0.02807029 0.02525422 0.01997234 0.02059787 0.02120497
#  0.01924842 0.01788681] [0.0003774  0.00205228 0.00194581 0.00193693 0.00195502 0.0016379
#  0.0008636  0.00140724 0.0020146  0.00162473 0.00305665 0.00252948
#  0.00179738 0.00172235]
# [ 0  8 16 23 31 38 45 51 57 62 68 73 77 81] [0.03915802 0.04480004 0.04255469 0.03772375 0.0357166  0.03247565
#  0.03213741 0.02653206 0.02325232 0.02450784 0.02051951 0.0223109
#  0.02014021 0.01968407] [0.0003774  0.00208504 0.00165126 0.00180761 0.00193062 0.00203088
#  0.00172493 0.00173289 0.00175551 0.00329684 0.00188872 0.00316918
#  0.00181543 0.00185753]
